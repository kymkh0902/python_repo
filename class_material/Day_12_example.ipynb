# %% [markdown]
# # Day 12
# ***
# ###  학습 목표
#
# #### 자동화 그리고 예측
#   - A,B,C,D 변수를 입력하여 원하는 결과 값 Y을 구하는 함수
#
#     - A,B,C,D를 **어떻게** 가져와서 **항상** 정확하게 원하는 값을 구할 것인가?
#
#         → *사람 손이 가장 안 타는 방향. (서버에서 데이터 받기)*
#
#
#   - 자동화가 필요한 이유
#
#     - 데이터 정확도 향상, 데이터로부터 다양한 의미 도출
#
#
#   - 자동화 이 후(예측)
#
#     - 수 많은 접근 가능한 데이터를 활용해서 무엇을 할 것인가?
#
#         → **머신러닝** : 데이터를 바탕으로 현재 상황에서 미래를 예측할 수 있게 함.
#
#
# 더 많은 데이터를 쉽게 다룰 수 있어야 현 상황에 대한 파악, 데이터의 정확도에 대한 고민을 할 수 있다고 생각합니다.
# 주로 성과와 연관된 데이터를 많이 다루세요. 그러다보면 정확하지 않고 관리되지 않는 부분들이 보일 겁니다.
# 사소한 부분부터 개선해 나가면 점점 더 정확한 데이터를 얻을 수 있고 이를 바탕으로 큰 성과를 이루실 수 있을 겁니다.
#
# 그리고 지속 가능한 모델을 만들어주세요. Github에서 하셨던 것처럼 항상 변경 사항을 공유하고 피드백을 받는 시스템을 구축한 다음에
# 업무를 진행하시면 목표에 도달하는 데에 도움이 많이 될 것입니다.
#
#
#
# **성과 창출 예시)**
# 1. RTS 재단 모델 별 수율 분석 진행 : 재단 시 유리한 모델 선정, 고객사 보상 협의, Chip 추적 가능
#
# 2. 실제 수율과 비교 : Chip 개수, Chip 내 마킹 유무 확인
#
# 3. 맞지 않는 점 확인 : 컨트롤 가능한 부분, 불가한 부분 확인
#
# 4. 개선 가능한 점 확인, 개선 시 예상 성과 파악 : 재단 시작점을 마킹하여 항상 재단이 일정하게 진행되도록 함.

# %%
# 예제2) Cpk Trend 구하기 

# 대상 : RC40 HC 

# 기간 : 17년 월 별 Cpk Trend

# 물성 : USL, LSL 있는 모든 물성 값

# 출력 : xlsx 파일
