# %% [markdown]
# # Day 5
# ***
# ###  학습 목표
#
# #### 1) Pandas package 학습
#   - Pandas 데이터 구조
#     1. DataFrame
#     2. Series
#
#
#   - Pandas 데이터 불러오기
#     1. read_csv
#     2. read_excel
#     3. read_sql_query
#
#
#   - Pandas 데이터 내용 확인
#     1. head
#     2. describe
#     3. iloc
#
#
#   - Pandas 데이터 가공
#     1. groupby
#     2. apply
#     3. merge
#     4. concat
#     5. cut
#     6. drop
#     7. dropna
#     8. fillna
#     9. mean/std/min/max/corr
#
#
#   - Pandas 데이터 내보내기
#     1. to_excel
#
#
# (Pandas API documentation : http://pandas.pydata.org/pandas-docs/stable/index.html)

# %% [markdown]
# ***
# ### Pandas 학습
#
# - **Pandas 데이터 구조**
#
#     1. DataFrame : 행, 열으로 이루어진 excel 데이터 형식이라고 생각하시면 됩니다.
#     ```python
#     import pandas as pd
#     data_frame = pd.DataFrame(data = [[1,2], [2,3]], columns = ['A','B'], index = ['a','b'])
#     ```
#     2. Series : 행 또는 열로 이루어진 데이터 형식으로 series가 모여서 dataframe이 됩니다.
#     ```python
#     import pandas as pd
#     data_series = pd.Series(data = [1,2], name = 'a')
#     ```

# %%
# 예제1) Dataframe를 생성해봅시다.

#1. pandas를 import합니다.

#2. 3*2(row*column) 형태의 dataframe 을 만들겠습니다.

#3. column명은 grade, qty로 명명해주고 index는 따로 추가하지 않습니다. 내용은 각자 채워주세요

# %% [markdown]
# - **Pandas 데이터 불러오기**
#
#     1. read_csv : txt, csv, xls 형식의 파일을 불러올 때 사용하는 함수입니다.
#     ```python
#     names = ['날짜','Lot','Frame수'...]                    # Column명을 names이라는 변수에 저장한다.
#     data = pd.read_csv('20160715DC02017.txt', sep = '\t',names = names)  # read_csv 함수를 이용해 20160715DC02017.txt 파일을 읽어 data 변수에 저장한다.
#     ```
#     2. read_excel : xlsx 형식의 파일을 불러올 때 사용하는 함수입니다.
#     ```python
#     names = ['날짜','Lot','Frame수'...]                                 # Column명을 names이라는 변수에 저장한다.
#     data = pd.read_excel('20160715DC02017.xlsx', sheetname = 'Sheet1')  # read_excel 함수를 이용해 20160715DC02017.xlsx 파일을 읽어 data 변수에 저장한다.
#     ```
#     3. read_sql_query : 데이터베이스에서 Query문을 통해 데이터를 가져올 때 사용하는 함수입니다.
#     ```python
#     # db1 데이터베이스에서 Lot가 20160715DC02017인 정보를 모두 가져와서 data라는 변수에 저장한다.
#     data = pd.read_sql_query("SELECT * FROM tb_iem120 WHERE unique_lot_no = '20160715DC02017'", db1)
#     ```

# %%
# 예제2) 자동검사기 파일을 불러옵니다.

names = ['날짜','Lot','Frame수', '카메라 번호', '사용안함', 'INDEX', '불량유형','X','y', 
         'X-Size','Y-Size', '불량이미지','사용안함','사용안함','Value','흑점','조명밝기']

#0. 현재 작업 폴더를 확인하고 optical_python 내 dataset이라는 폴더를 작업 폴더로 만들어주세요. 

#1. dataset라는 폴더 내에 20160715DC02017.txt 파일을 read_csv 함수를 이용해서 불러와보세요. (변수 : data_1)

#2. dataset라는 폴더 내에 20160715DC02017.xlsx 파일을 read_excel 함수를 이용해서 불러와보세요. (변수 : data)

import pandas as pd
data = pd.read_csv('20160715DC02017.txt', sep = '\t', names = names)

# %% [markdown]
# - **Pandas 데이터 내용 확인**
#     1. head : 데이터 가장 상단의 몇 줄만 확인할 때 사용합니다. (주로 데이터가 잘 불러졌는 지 확인할 때 사용.)
#     ```python
#     data.head(5)     # data row 5개 줄을 확인합니다.
#     ```
#
#     2. describe : 데이터의 기본적인 통계 수치를 확인할 때 사용합니다. (max, min, mean, std 등)
#
#     ```python
#     data.describe()
#     ```
#
#     3. iloc : 데이터의 행, 열을 지정하여 불러오거나 특정 범위만큼 선택할 때 사용합니다.
#
#     ```python
#     data.iloc[1,1]   # data의 2열 2행의 값을 확인합니다.
#     data.iloc[1:, 1] # data의 2~열 2행의 값을 확인합니다.
#     ```
#
#     4. columns, index : column과 index로 지정된 값을 확인합니다.
#     ```python
#     data.columns  # data의 column을 확인합니다.
#     data.index    # data의 index를 확인합니다.
#     ```

# %%
# 예제3) 위에서 불러온 data라는 변수의 기본적인 내용 확인 과정입니다.

#1. data의 상단 10줄을 head라는 함수를 사용해서 출력해보세요 

#2. data의 기본 통계 수치를 describe 함수를 사용해서 출력해보세요 

#3. data의 전체 열, 3~행을 iloc을 사용해서 출력해보세요. 

#4. data의 1열 1행의 값에 숫자 3을 대입해보세요. 값이 바뀌나요?
# Out:
#        20160715221052             7          901       0         0.1  \
# count    2.347000e+03   2347.000000  2347.000000  2347.0  2347.00000
# mean     2.016072e+13  15436.481892   412.048147     0.0     0.58202
# std      1.748419e+03   6138.778052   380.220632     0.0     1.04481
# min      2.016072e+13      1.000000   101.000000     0.0     0.00000
# 25%      2.016072e+13  13492.000000   122.000000     0.0     0.00000
# 50%      2.016072e+13  19028.000000   122.000000     0.0     0.00000
# 75%      2.016072e+13  19202.000000   922.000000     0.0     1.00000
# max      2.016072e+13  19631.000000   923.000000     0.0     4.00000
#
#                 2305        32.99        15.84          0.225          0.293  \
# count    2339.000000  2345.000000  2343.000000    2339.000000    2347.000000
# mean    44967.989312  1740.022674    24.280218     117.760702     117.527294
# std     38811.407108   611.101419    16.013936    3977.234603    3970.449081
# min       257.000000     0.000000     0.000000   -2294.000000   -2294.000000
# 25%      2305.000000  1585.900000    11.300000       0.075000       0.220000
# 50%     65793.000000  2069.050000    22.890000       0.150000       0.293000
# 75%     65793.000000  2074.740000    35.870000       0.225000       0.367000
# max    110553.000000  2191.180000   104.980000  115530.000000  115530.000000
#
#           0.2       344.4697             42            255           63
# count  2347.0    2347.000000    2341.000000    2338.000000  2347.000000
# mean      0.0  730282.981201    1986.472448    2179.315227    61.857661
# std       0.0  282108.139741   15117.214456   15102.338103     4.710943
# min       0.0      62.207100   -2294.000000   -2294.000000    59.000000
# 25%       0.0  639873.895900      26.000000     255.000000    60.000000
# 50%       0.0  893498.457200      35.000000     255.000000    61.000000
# 75%       0.0  901516.394200      53.000000     255.000000    62.000000
# max       0.0  921623.650100  192918.000000  192918.000000   111.000000

# %%
data[data['Value']<100]
# Out:
#                   날짜              Lot  Frame수  카메라 번호         사용안함  INDEX  \
# 0     20160715221052  20160715DC02017       7     901     344.4697      0
# 1     20160715221122  20160715DC02017     321     901   15103.2491      0
# 2     20160715221239  20160715DC02017    1139     901   53509.9369      0
# 4     20160715222855  20160715DC02017   11441     901  537153.0911      0
# 5     20160715222952  20160715DC02017   12042     901  565383.6282      0
# 6     20160715223137  20160715DC02017   13148     901  617287.4608      0
# 11    20160715221322  20160715DC02017    1013     902   47590.3523      0
# 13    20160715222920  20160715DC02017   11127     902  522398.5717      0
# 15    20160715224012  20160715DC02017   18004     902  845264.2684      0
# 16    20160715221228  20160715DC02017     106     903    4986.5926      0
# 17    20160715221344  20160715DC02017     902     903   42371.6642      0
# 18    20160715221515  20160715DC02017    1861     903   87375.3731      0
# 19    20160715221533  20160715DC02017    2052     903   96337.8692      0
# 20    20160715221541  20160715DC02017    2142     903  100577.8582      0
# 21    20160715221912  20160715DC02017    4361     903  204776.1331      0
# 22    20160715222050  20160715DC02017    5402     903  253635.1542      0
# 23    20160715222352  20160715DC02017    7323     903  343821.1933      0
# 24    20160715222727  20160715DC02017    9587     903  450086.3977      0
# 28    20160715221213  20160715DC02017      55     904    2601.4605      0
# 29    20160715221333  20160715DC02017     902     904   42386.1942      0
# 32    20160715222955  20160715DC02017   11271     904  529156.1641      0
# 33    20160715223356  20160715DC02017   13814     904  648538.6094      0
# 35    20160715223620  20160715DC02017   15332     904  719806.8772      0
# 36    20160715223657  20160715DC02017   15722     904  738112.7962      0
# 38    20160715222054  20160715DC02017    5550     905  260584.2050      0
# 41    20160715222828  20160715DC02017   10341     905  485515.2411      0
# 44    20160715223719  20160715DC02017   15943     905  748502.6253      0
# 45    20160715221058  20160715DC02017      46     906    2184.2166      0
# 46    20160715221219  20160715DC02017     901     906   42329.1971      0
# 47    20160715221228  20160715DC02017     994     906   46687.1274      0
# ...              ...              ...     ...     ...          ...    ...
# 2318  20160715224244  20160715DC02017   19350     122  908444.6550      0
# 2319  20160715224244  20160715DC02017   19350     122  908443.8450      1
# 2320  20160715224244  20160715DC02017   19351     122  908491.8221      0
# 2321  20160715224244  20160715DC02017   19353     122  908613.0763      0
# 2322  20160715224246  20160715DC02017   19370     122  909386.3070      0
# 2323  20160715224247  20160715DC02017   19378     122  909775.0138      0
# 2324  20160715224247  20160715DC02017   19380     122  909856.2180      0
# 2325  20160715224247  20160715DC02017   19380     122  909850.7180      1
# 2326  20160715224247  20160715DC02017   19380     122  909838.1680      2
# 2327  20160715224248  20160715DC02017   19390     122  910320.7690      0
# 2328  20160715224249  20160715DC02017   19400     122  910790.9100      0
# 2329  20160715224249  20160715DC02017   19401     122  910828.7571      0
# 2330  20160715224251  20160715DC02017   19421     122  911770.3391      0
# 2331  20160715224252  20160715DC02017   19430     122  912196.0130      0
# 2332  20160715224252  20160715DC02017   19437     122  912550.6927      0
# 2333  20160715224254  20160715DC02017   19449     122  913086.1779      0
# 2334  20160715224254  20160715DC02017   19450     122  913137.0850      0
# 2335  20160715224255  20160715DC02017   19469     122  914024.0199      0
# 2336  20160715224256  20160715DC02017   19470     122  914075.8770      0
# 2337  20160715224257  20160715DC02017   19483     122  914709.8093      0
# 2338  20160715224257  20160715DC02017   19490     122  915013.6490      0
# 2339  20160715224257  20160715DC02017   19490     122  915009.9790      1
# 2340  20160715224258  20160715DC02017   19491     122  915056.7061      0
# 2341  20160715224300  20160715DC02017   19518     122  916353.4078      0
# 2342  20160715224300  20160715DC02017   19520     122  916450.6020      0
# 2343  20160715224301  20160715DC02017   19530     122  916886.1030      0
# 2344  20160715224309  20160715DC02017   19608     122  920548.4168      0
# 2345  20160715224311  20160715DC02017   19631     122  921623.6501      0
# 2346  20160715224151  20160715DC02017   19224     123  902521.6104      0
# 2347  20160715224153  20160715DC02017   19243     123  903420.6553      0
#
#         불량유형        X      y    X-Size    Y-Size  \
# 0       2305    32.99  15.84     0.225     0.293
# 1       2305    36.44  33.23     0.300     0.587
# 2       2305    41.40  37.19     0.526     0.440
# 4       2305    42.75  31.32     0.526     0.367
# 5       2305    45.23  46.65     0.225     0.293
# 6       2305    43.72  26.99     0.225     0.293
# 11      2305    80.53  32.94     0.150     0.440
# 13      2305   130.18  18.19     0.225     0.440
# 15      2305   100.51  28.68     0.150     0.293
# 16      2305   237.25  10.20     0.375     0.660
# 17      2305   233.20  25.38     0.300     0.440
# 18      2305   190.77   6.82     0.150     0.367
# 19      2305   199.78   2.42     0.225     0.293
# 20      2305   204.81  17.17     0.225     0.367
# 21      2305   191.74  39.83     0.150     0.293
# 22      2305   188.82  26.92     0.225     0.660
# 23      2305   229.44  27.58     0.150     0.293
# 24      2305   190.69   4.55     0.150     0.367
# 28      2305   324.17  19.37     0.225     0.220
# 29     67843   321.24  39.91 -1142.000 -1142.000
# 32      2305   314.18  15.40     0.225     0.293
# 33      2305   258.00  11.37     0.225     0.293
# 35      2305   293.53  13.94     0.150     0.293
# 36      2305   302.99  10.49     0.300     0.440
# 38      2305   407.02  27.80     0.150     0.293
# 41      2305   410.40  35.28     0.300     0.513
# 44      2305   387.49  25.01     0.375     0.220
# 45      2305   537.91  24.65     0.225     0.293
# 46      2305   517.56  29.86     0.300     0.367
# 47      2305   458.91  21.71     0.225     0.293
# ...      ...      ...    ...       ...       ...
# 2318  107432  2078.88  18.27     0.225     0.440
# 2319  107252  2071.45  17.46     0.150     0.220
# 2320   65793  2062.23  18.49     0.075     0.220
# 2321   65793  2073.18  45.85     0.075     0.220
# 2322  107432  2072.57  20.98     0.150     0.220
# 2323  107553  2073.55  34.11     0.075     0.220
# 2324   65793  2076.32  21.42     0.075     0.220
# 2325   65793  2072.35  15.92     0.075     0.220
# 2326   65793  2074.38   3.37     0.075     0.220
# 2327   65793  2078.88  16.50     0.075     0.220
# 2328  107432  2073.48  17.17     0.075     0.220
# 2329  107446  2073.63   8.07     0.075     0.220
# 2330   65793  2062.07  10.71     0.075     0.220
# 2331   65793  2078.88  13.86     0.150     0.220
# 2332   65793  2111.73  39.91     0.075     0.220
# 2333   65793  2068.82  12.03     0.075     0.220
# 2334   65793  2072.57  15.99     0.075     0.220
# 2335  107432  2068.82  10.93     0.075     0.220
# 2336  107432  2072.43  15.84     0.075     0.220
# 2337   65793  2095.00  39.46     0.075     0.220
# 2338  107432  2072.73  14.67     0.075     0.220
# 2339   65793  2078.95  11.00     0.075     0.220
# 2340   65793  2062.00  10.78     0.075     0.220
# 2341   65793  2078.95  39.91     0.075     0.220
# 2342   65793  2075.65  43.21     0.150     0.220
# 2343  107272  2078.95   9.24     0.075     0.220
# 2344   65793  2087.95   9.68     0.075     0.220
# 2345   65793  2062.23   5.13     0.075     0.220
# 2346   65795  2140.25  10.56     0.000     0.000
# 2347     259  2140.18  17.61     0.000     0.000
#
#                                                   불량이미지         사용안함  \
# 0     20160715DC02017\NEL-901\NEL-901[22-10-52]_[000...     344.4697
# 1     20160715DC02017\NEL-901\NEL-901[22-11-22]_[000...   15103.2491
# 2     20160715DC02017\NEL-901\NEL-901[22-12-39]_[001...   53509.9369
# 4     20160715DC02017\NEL-901\NEL-901[22-28-55]_[011...  537153.0911
# 5     20160715DC02017\NEL-901\NEL-901[22-29-52]_[012...  565383.6282
# 6     20160715DC02017\NEL-901\NEL-901[22-31-37]_[013...  617287.4608
# 11    20160715DC02017\NEL-902\NEL-902[22-13-22]_[001...   47590.3523
# 13    20160715DC02017\NEL-902\NEL-902[22-29-20]_[011...  522398.5717
# 15    20160715DC02017\NEL-902\NEL-902[22-40-12]_[018...  845264.2684
# 16    20160715DC02017\NEL-903\NEL-903[22-12-28]_[000...    4986.5926
# 17    20160715DC02017\NEL-903\NEL-903[22-13-44]_[000...   42371.6642
# 18    20160715DC02017\NEL-903\NEL-903[22-15-15]_[001...   87375.3731
# 19    20160715DC02017\NEL-903\NEL-903[22-15-33]_[002...   96337.8692
# 20    20160715DC02017\NEL-903\NEL-903[22-15-41]_[002...  100577.8582
# 21    20160715DC02017\NEL-903\NEL-903[22-19-12]_[004...  204776.1331
# 22    20160715DC02017\NEL-903\NEL-903[22-20-50]_[005...  253635.1542
# 23    20160715DC02017\NEL-903\NEL-903[22-23-52]_[007...  343821.1933
# 24    20160715DC02017\NEL-903\NEL-903[22-27-27]_[009...  450086.3977
# 28    20160715DC02017\NEL-904\NEL-904[22-12-13]_[000...    2601.4605
# 29    20160715DC02017\NEL-904\NEL-904[22-13-33]_[000...   42386.1942
# 32    20160715DC02017\NEL-904\NEL-904[22-29-55]_[011...  529156.1641
# 33    20160715DC02017\NEL-904\NEL-904[22-33-56]_[013...  648538.6094
# 35    20160715DC02017\NEL-904\NEL-904[22-36-20]_[015...  719806.8772
# 36    20160715DC02017\NEL-904\NEL-904[22-36-57]_[015...  738112.7962
# 38    20160715DC02017\NEL-905\NEL-905[22-20-54]_[005...  260584.2050
# 41    20160715DC02017\NEL-905\NEL-905[22-28-28]_[010...  485515.2411
# 44    20160715DC02017\NEL-905\NEL-905[22-37-19]_[015...  748502.6253
# 45    20160715DC02017\NEL-906\NEL-906[22-10-58]_[000...    2184.2166
# 46    20160715DC02017\NEL-906\NEL-906[22-12-19]_[000...   42329.1971
# 47    20160715DC02017\NEL-906\NEL-906[22-12-28]_[000...   46687.1274
# ...                                                 ...          ...
# 2318  20160715DC02017\NEL-122\NEL-122[22-42-44]_[019...  908444.6550
# 2319  20160715DC02017\NEL-122\NEL-122[22-42-44]_[019...  908443.8450
# 2320  20160715DC02017\NEL-122\NEL-122[22-42-44]_[019...  908491.8221
# 2321  20160715DC02017\NEL-122\NEL-122[22-42-44]_[019...  908613.0763
# 2322  20160715DC02017\NEL-122\NEL-122[22-42-46]_[019...  909386.3070
# 2323  20160715DC02017\NEL-122\NEL-122[22-42-47]_[019...  909775.0138
# 2324  20160715DC02017\NEL-122\NEL-122[22-42-47]_[019...  909856.2180
# 2325  20160715DC02017\NEL-122\NEL-122[22-42-47]_[019...  909850.7180
# 2326  20160715DC02017\NEL-122\NEL-122[22-42-47]_[019...  909838.1680
# 2327  20160715DC02017\NEL-122\NEL-122[22-42-48]_[019...  910320.7690
# 2328  20160715DC02017\NEL-122\NEL-122[22-42-49]_[019...  910790.9100
# 2329  20160715DC02017\NEL-122\NEL-122[22-42-49]_[019...  910828.7571
# 2330  20160715DC02017\NEL-122\NEL-122[22-42-51]_[019...  911770.3391
# 2331  20160715DC02017\NEL-122\NEL-122[22-42-52]_[019...  912196.0130
# 2332  20160715DC02017\NEL-122\NEL-122[22-42-52]_[019...  912550.6927
# 2333  20160715DC02017\NEL-122\NEL-122[22-42-54]_[019...  913086.1779
# 2334  20160715DC02017\NEL-122\NEL-122[22-42-54]_[019...  913137.0850
# 2335  20160715DC02017\NEL-122\NEL-122[22-42-55]_[019...  914024.0199
# 2336  20160715DC02017\NEL-122\NEL-122[22-42-56]_[019...  914075.8770
# 2337  20160715DC02017\NEL-122\NEL-122[22-42-57]_[019...  914709.8093
# 2338  20160715DC02017\NEL-122\NEL-122[22-42-57]_[019...  915013.6490
# 2339  20160715DC02017\NEL-122\NEL-122[22-42-57]_[019...  915009.9790
# 2340  20160715DC02017\NEL-122\NEL-122[22-42-58]_[019...  915056.7061
# 2341  20160715DC02017\NEL-122\NEL-122[22-43-00]_[019...  916353.4078
# 2342  20160715DC02017\NEL-122\NEL-122[22-43-00]_[019...  916450.6020
# 2343  20160715DC02017\NEL-122\NEL-122[22-43-01]_[019...  916886.1030
# 2344  20160715DC02017\NEL-122\NEL-122[22-43-09]_[019...  920548.4168
# 2345  20160715DC02017\NEL-122\NEL-122[22-43-11]_[019...  921623.6501
# 2346  20160715DC02017\NEL-123\NEL-123[22-41-51]_[019...  902521.6104
# 2347  20160715DC02017\NEL-123\NEL-123[22-41-53]_[019...  903420.6553
#
#              사용안함   Value      흑점   조명밝기
# 0        344.4697    42.0   255.0  63.00
# 1      15103.2491    36.0   255.0  64.00
# 2      53509.9369    47.0   255.0  63.00
# 4     537153.0911    37.0   255.0  63.00
# 5     565383.6282    25.0   255.0  63.00
# 6     617287.4608    32.0   255.0  63.00
# 11     47590.3523    23.0   255.0  62.00
# 13    522398.5717    60.0   255.0  62.00
# 15    845264.2684    26.0   255.0  62.00
# 16      4986.5926    90.0   255.0  60.00
# 17     42371.6642    56.0   255.0  61.00
# 18     87375.3731    58.0   255.0  60.00
# 19     96337.8692    25.0   255.0  60.00
# 20    100577.8582    89.0   255.0  61.00
# 21    204776.1331    29.0   255.0  60.00
# 22    253635.1542    64.0   255.0  60.00
# 23    343821.1933    26.0   255.0  60.00
# 24    450086.3977    55.0   255.0  61.00
# 28      2601.4605    43.0   255.0  61.00
# 29     42386.1942 -1142.0 -1142.0  62.00
# 32    529156.1641    94.0   255.0  61.00
# 33    648538.6094    36.0   255.0  62.00
# 35    719806.8772    39.0   255.0  62.00
# 36    738112.7962    51.0   255.0  62.00
# 38    260584.2050    59.0   255.0  59.00
# 41    485515.2411    89.0   255.0  59.00
# 44    748502.6253    21.0   255.0  59.00
# 45      2184.2166    35.0   255.0  64.07
# 46     42329.1971    69.0   255.0  64.42
# 47     46687.1274    41.0   255.0  64.79
# ...           ...     ...     ...    ...
# 2318  908444.6550    69.0   255.0  60.00
# 2319  908443.8450    34.0   255.0  60.00
# 2320  908491.8221    22.0   255.0  60.00
# 2321  908613.0763    24.0   255.0  60.00
# 2322  909386.3070    29.0   255.0  60.00
# 2323  909775.0138    37.0   255.0  60.00
# 2324  909856.2180    25.0   255.0  60.00
# 2325  909850.7180    24.0   255.0  60.00
# 2326  909838.1680    22.0   255.0  60.00
# 2327  910320.7690    50.0   255.0  59.00
# 2328  910790.9100    23.0   255.0  60.00
# 2329  910828.7571    26.0   255.0  60.00
# 2330  911770.3391    32.0   255.0  60.00
# 2331  912196.0130    23.0   255.0  60.00
# 2332  912550.6927    30.0   255.0  60.00
# 2333  913086.1779    28.0   255.0  60.00
# 2334  913137.0850    28.0   255.0  60.00
# 2335  914024.0199    20.0   255.0  60.00
# 2336  914075.8770    28.0   255.0  60.00
# 2337  914709.8093    27.0   255.0  60.00
# 2338  915013.6490    30.0   255.0  60.00
# 2339  915009.9790    24.0   255.0  60.00
# 2340  915056.7061    34.0   255.0  59.00
# 2341  916353.4078    25.0   255.0  60.00
# 2342  916450.6020    51.0   255.0  60.00
# 2343  916886.1030    21.0   255.0  59.00
# 2344  920548.4168    26.0   255.0  60.00
# 2345  921623.6501    38.0   255.0  60.00
# 2346  902521.6104 -1015.0 -1015.0  61.00
# 2347  903420.6553 -1400.0 -1400.0  61.00
#
# [2169 rows x 17 columns]

# %% [markdown]
# - **Pandas 데이터 선택**
#
#     1. 기본 내용 :
#
#         - 기본적으로 행/열 선택 시 [ ] (**Series**), [[ ]] (**DataFrame**) 방식으로 선택할 수 있습니다. 물론 Series는 1개 행/열만 해당합니다.
#
#         - 1개 행/열 선택 시에는 data[행이름/열이름] (**Series**) 혹은 data[[행이름/열이름]] (**DataFrame**) 형식으로 선택할 수 있습니다.
#
#         - 다수 행/열 선택 시에는 data[['행이름1, 행이름2, ...']] 의 형식으로 선택할 수 있습니다. (**DataFrame**)
#
#         - 특정 조건을 가진 데이터를 선택하실 때는 원하는 행에 조건을 걸어 boolean으로 만들어 준 후 data내에서 True값만 반환합니다.
#         ```python
#         data[data['col1'] > 5] # col1행 값 중 5보다 큰 값의 index에 해당되는 data를 가져옵니다.
#         data[(data['col1'] > 5) & (data['col1'] < 10)]  # col1행 값 중 5보다 크고 10보다 작은 값의 index에 해당되는 data를 가져옵니다.
#         ```
#
#     2. 행 선택 : 아래와 같은 방법으로 행을 선택해서 가져올 수 있습니다.(DataFrame, Series 둘 중에 아무거나 쓰셔도 됩니다.)
#     ```python
#     data['col1']           # col1행만 가져옵니다.
#     data[data['col1'] >5]  # col1행 값 중 5보다 큰 값의 index에 해당되는 data를 가져옵니다.
#     ```
#
#     3. 열 선택 : 아래와 같은 방법으로 열을 선택해서 가져올 수 있습니다.(자주 안 씁니다. 주로 iloc만 아시면 되요)
#     ```python
#     data.iloc[0]           # 0번째 index의 값을 가져옵니다.
#     data.loc[0]            # 0이라는 index의 값을 가져옵니다.
#     data.T[0]              # 0이라는 index의 값을 가져옵니다.
#     ```
#
#     4. 행/열 변환 : 행, 열의 배열을 뒤집어서 나타내줍니다. (엑셀에 붙여넣기에 존재하는 기능이죠.)
#     ```python
#     data.T                 # data의 행, 열의 배열을 뒤집어서 나타내줍니다.
#     ```

# %%
# 예제4) 행, 열 선택을 통한 원하는 데이터만 가져오기

#1. 위에서 불러온 data 변수에서 '불량유형' 행만 선택해서 나타내봅니다.

#2. '불량유형' 행의 값이 2305인 조건을 걸어보고, data 내 해당 조건을 만족하는 값들만 나타내보고 변수 data_2305에 저장합니다.

# %% [markdown]
# - **Pandas 데이터 가공**
#
#     1. drop : 데이터를 삭제합니다. 삭제하는 방향에 따라 다르게 적용할 수 있습니다. (열, 행 방향)
#     ```python
#     data.drop('col1', axis = 1, inplace = True)         # data의 col1행을 1(행 방향으로) 삭제하고 변수에 저장합니다.
#     data = data.drop('col1', axis = 1, inplace = False) # 위와 같은 내용입니다.
#     ```
#     2. dropna : na값의 데이터를 삭제합니다. na에는 NaN, None 등의 값(데이터 없음)들이 포함됩니다.
#     ```python
#     data = pd.DataFrame(data = [[None, 1], [2, 0], [1, 2], [3, 4]], columns = ['num1','num2'])  # 2*4 형태의 data를 만듭니다.
#     data.dropna()   # 설정을 default 값으로 한 후에 실행합니다.
#     data.dropna(axis = 0, how = 'any', subset = ['num1'])  # 열 방향으로, num1행에 대해서 모든(any)na에 대해 drop합니다.
#     ```
#     3. fillna : na값의 데이터를 원하는 값으로 채워줍니다.
#     ```python
#     data = pd.DataFrame(data = [[None, 1], [2, 0], [1, 2], [3, 4]], columns = ['num1','num2'])  # 2*4 형태의 data를 만듭니다.
#     data.fillna(0, inplace = True)  # na값을 0이라는 숫자로 채우고 적용하고 변수에 저장합니다.
#     data = data.fillna(0)           # 위와 같은 내용입니다.
#     ```
#
#     4. cut : Series의 숫자 data를 원하는 범위만큼 잘라서 구분해줍니다. 그리고 해당 범위에 label을 붙여줍니다.
#     ```python
#     data = pd.DataFrame(data = [i for i in range(0,20)], columns = ['num1'])
#     # 값을 0, 5, 10, 20 으로 구분하고 그룹화합니다. 그리고 그룹에 순서대로 매칭되는 label을 붙여줍니다.
#     pd.cut(data['num1'], bins = [0, 5, 10, 20], labels = ['0~5','5~10','10~20'], include_lowest = True)
#     ```
#
#     5. mean/std/min/max/corr : 주요 기초 통계 값들을 불러올 때 사용합니다. DataFrame, Series 모두에 사용해도 무방하며 숫자로 이루어진 행만 출력될 것입니다.
#     ```python
#     data = pd.DataFrame(data = [['a',1, 3],['b',2, 4],['c',3, 6]], columns = ['alp','num1','num2'])
#     data.mean()  # 평균 값을 가져옵니다.
#     data.std()   # 표준편차 값을 가져옵니다.
#     data.min()   # 최대값을 가져옵니다.
#     data.max()   # 최소값을 가져옵니다.
#     data.corr()  # 상관관계 나타냅니다.
#     ```
#
#     6. apply : 한 행 또는 열에 대해서 함수를 적용시켜 값을 변환합니다. lambda와 함께 사용 시 제어문, 함수를 동시에 사용하여 apply 내에 복잡한 값 변환을 할 수 있습니다. Series 형태의 데이터만 apply가 적용 가능합니다.
#     ```python
#     data['col1'].apply(lambda x: x+1)  # col1 행에 대해 함수를 적용해서 내용을 바꿔줍니다.(x → x+1)
#     ```
#
#     8. concat : DataFrame 또는 Series를 합칠 때 사용합니다. 합치는 방향에 따라 다르게 적용할 수 있습니다. (열, 행 방향)
#     ```python
#     data_1 = pd.DataFrame(data = [1,2])
#     data_2 = pd_DataFrame(data = [2,3])
#     data_concat_0 = pd.merge([data_1, data_2], axis = 0)  # 아래로 쌓습니다.(열 개수 증가.)
#     data_concat_1 = pd.merge([data_1, data_2], axis = 1)  # 옆으로 쌓습니다.(행 개수 증가.)
#     ```
#
#     9. merge :
#
#     10. groupby : 엑셀의 pivot의 행 레이블에 들어가는 값이 groupby 내에 들어가고 값 레이블에 들어가는 값이 이후 [[ ]] (dataframe) 안에 들어가게 됩니다. 그 다음에 행하려는 함수를 입력해줍니다.
#     ```python
#     data.groupby(['col1','col2'])[['col3', 'col4']].sum()  # data를 col1, col2로 묶고 col3, col4에 대해 sum()함수를 적용합니다.
#     ```

# %%
names = ['날짜','Lot','Frame수', '카메라 번호', '사용안함', 'INDEX', '불량유형','X','y', 
         'X-Size','Y-Size', '불량이미지','사용안함','사용안함','Value','흑점','조명밝기']

# 예제5) 데이터 가공

#1. 위에서 불러온 검사기 data_2305에서 필요한 행만 남기고 지울 예정입니다. 
  # 행 이름(names)을 참고하셔서 '불량유형','X','y','X-Size','Y-Size','Value'를 제외한 행을 다 삭제하고 저장해주세요
    
#2. data_2305에 na값들을 넣어놨습니다. 아래 코드를 실행해서 값을 확인하고 다 지워보고(dropna) 원하시는 값으로 채워보세요 (fillna)

data_2305[data_2305.isnull().any(axis=1)] # null 값이 있는 열을 나타내줍니다. 

#3. data_2305의 mean/std/min/max/corr을 확인해보세요 

#4. data_2305의 'Value' 행을 값의 범위 별로 나눈 후에 새로운 'cut'이라는 행에 저장하겠습니다. 
  # max로 최대값을 확인하신 후에 0부터 최대값까지 원하시는 만큼 쪼개보세요. 매칭할 label은 '0~30', '30~60'와 같은 범위로 나타내주세요.
